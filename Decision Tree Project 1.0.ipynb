# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('https://raw.githubusercontent.com/training-ml/Files/main/wine.csv')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol Alcohol_content  quality
# 0      9.4             Low        5
# ...

# %%
data.shape
# Out:
# (1599, 13)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# Alcohol_content         0
# quality                 0
# dtype: int64

# %% [markdown]
# We dont have null . but we have to find one categorical data . in Alcohol_content  and its follow some order  in think we have to conver in numbers by using ordinal encoder

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df1=OrdinalEncoder(categories=[['Low','Medium','High']])
df2=df1.fit_transform(data[['Alcohol_content']])
df2
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [2.],
#        [1.],
#        [2.]])

# %%
#Override the Alcohol_content  with new values

# %%
data['Alcohol_content']=df2
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#Now we have to check multicollinearty problem. with the use of HeatMap

# %%
df_corr=data.corr().abs()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df_corr,data=data,annot=True,annot_kws={'size':20})
plt.show()

# %%
#We seen all the data we gind good relationship between alcohol and alcohol content.
#but we dont have any proof . lets check with other visualization techniques

# %%
plt.scatter(x='alcohol',y='Alcohol_content',data=data)
plt.xlabel('alcohol')
plt.ylabel('Alcohol_content')
plt.title('Alcohol_content vs Alcohol Content')
plt.show()

# %% [markdown]
# after seeing in the scatter we confirm that . litressly theres is a good relationship. . now we have to delete one feature.
#
#
#
# But there is a question Which column we have to take which column we have to delete.
# so which feature has more relationship that one we have to taken.
#
#
# so there is alcohol has take more relatioship with label so we have to delete the alcohol content.

# %%
x=data.drop(columns=['Alcohol_content','quality'])
y=data.quality

# %% [markdown]
# #Now we have to do train test spllit we are not standadizing the data because decision tree will take care of it.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=94255)

# %%
def metrics_score(cnn,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=cnn.predict(x_train)
        print("=============== Training Score===========")
        print("Accuracy Score====",accuracy_score(y_train,y_pred)*100)
    elif train==False:
        pred=cnn.predict(x_test)
        print("===============Testing Score==============")
        print("Accuracy Score   ",accuracy_score(y_test,pred)*100)
        print("Classification Report ==>", classification_report(y_test,pred))

# %%
#Now lets create model. with the help of decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,classification_report,roc_auc_score,roc_curve,confusion_matrix

# %%
cnn=DecisionTreeClassifier()

# %%
cnn.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
metrics_score(cnn,x_train,x_test,y_train,y_test,train=True)
metrics_score(cnn,x_train,x_test,y_train,y_test,train=False)
# Out:
# =============== Training Score===========
# Accuracy Score==== 100.0
# ===============Testing Score==============
# Accuracy Score    62.0
# Classification Report ==>               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00        11
#            5       0.67      0.73      0.70       166
#            6       0.63      0.57      0.60       160
#            7       0.53      0.60      0.56        57
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.62       400
#    macro avg       0.31      0.32      0.31       400
# weighted avg       0.61      0.62      0.61       400

# %%
#So basically our model is overfitted . in decision tree most of the time model is overfitted.
#so we have change our parameters .with the help of hyperparameter techniques.

# %%
#Lets import Hyperparameter tunning techiniques

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid= {'criterion':['gini', 'entropy'],
            'max_depth':range(6,17),
            'min_samples_split':range(3,15),
            'min_samples_leaf':range(2,10),
            'max_leaf_nodes':range(4,30)}

# %%
grid_search=GridSearchCV(estimator=cnn,param_grid=param_grid,cv=8,n_jobs=-1)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=8,
#              estimator=DecisionTreeClassifier(criterion='entropy', max_depth=19,
#                                               max_leaf_nodes=16,
#                                               min_samples_leaf=23,
#                                               min_samples_split=15),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(6, 17),
#                          'max_leaf_nodes': range(4, 30),
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(3, 15)})

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 8,
#  'max_leaf_nodes': 29,
#  'min_samples_leaf': 9,
#  'min_samples_split': 3}

# %%
cnn=DecisionTreeClassifier(criterion='entropy',max_depth=8,max_leaf_nodes=29,min_samples_leaf=9,min_samples_split=3)

# %%
cnn.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=8, max_leaf_nodes=29,
#                        min_samples_leaf=9, min_samples_split=3)

# %%
metrics_score(cnn,x_train,x_test,y_train,y_test,train=True)
metrics_score(cnn,x_train,x_test,y_train,y_test,train=False)
# Out:
# =============== Training Score===========
# Accuracy Score==== 66.38865721434529
# ===============Testing Score==============
# Accuracy Score    56.99999999999999
# Classification Report ==>               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00        11
#            5       0.66      0.66      0.66       166
#            6       0.53      0.58      0.55       160
#            7       0.51      0.44      0.47        57
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.57       400
#    macro avg       0.28      0.28      0.28       400
# weighted avg       0.56      0.57      0.56       400

# %%
#Student Of DataTrained 
#Student of DataScience -Saurav
#Date - 15-09-2022
#Time - 13:09
